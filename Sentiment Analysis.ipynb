# %%
from IPython.core.interactiveshell import InteractiveShell
InteractiveShell.ast_node_interactivity = "all"
import warnings
warnings.filterwarnings('ignore')
import pandas as pd
import numpy as np

# %%
df1 = pd.read_csv('C:/Users/zhou/Desktop/BIA 660/000--Project/3 - final/ted_talks_data_clean.csv')

df1['topic+desc'] = df1[['topics','descriptions']].agg(' '.join, axis=1)
df1.head(3)
df1['topic+desc'][0]
# Out:
#        speakers durations                                             topics  \
# 0  James Veitch   0:09:48  This is what happens when you reply to spam email
# 1     Amy Cuddy   0:21:02           Your body language may shape who you are
# 2   Simon Sinek   0:18:04                   How great leaders inspire action
#
#       views                                       descriptions  \
# 0  63440723  Suspicious emails: unclaimed insurance bonds, ...
# 1  59281283  (NOTE: Some of the findings presented in this ...
# 2  52322192  Simon Sinek has a simple but powerful model fo...
#
#                                                 tags  \
# 0    comedy|curiosity|communication|humor|technology
# 1  body language|brain|business|psychology|self|s...
# 2      TEDx|business|entrepreneur|leadership|success
#
#                                           topic+desc
# 0  This is what happens when you reply to spam em...
# 1  Your body language may shape who you are (NOTE...
# 2  How great leaders inspire action Simon Sinek h...
# 'This is what happens when you reply to spam email Suspicious emails: unclaimed insurance bonds, diamond-encrusted safe deposit boxes, close friends marooned in a foreign country. They pop up in our inboxes, and standard procedure is to delete on sight. But what happens when you reply? Follow along as writer and comedian James Veitch narrates a hilarious, weeks-long exchange with a spammer who offered to cut him in on a hot deal.'

# %%
text1 = list(df1['topic+desc'][:1000])
text1[:3]
# Out:
# ['This is what happens when you reply to spam email Suspicious emails: unclaimed insurance bonds, diamond-encrusted safe deposit boxes, close friends marooned in a foreign country. They pop up in our inboxes, and standard procedure is to delete on sight. But what happens when you reply? Follow along as writer and comedian James Veitch narrates a hilarious, weeks-long exchange with a spammer who offered to cut him in on a hot deal.',
#  'Your body language may shape who you are (NOTE: Some of the findings presented in this talk have been referenced in an ongoing debate among social scientists about robustness and reproducibility. Read "Criticisms &amp; updates" below for more details as well as Amy Cuddy\'s response.) Body language affects how others see us, but it may also change how we see ourselves. Social psychologist Amy Cuddy argues that "power posing" -- standing in a posture of confidence, even when we don\'t feel confident -- can boost feelings of confidence, and might have an impact on our chances for success.',
#  'How great leaders inspire action Simon Sinek has a simple but powerful model for inspirational leadership -- starting with a golden circle and the question: "Why?"  His examples include Apple, Martin Luther King Jr. and the Wright brothers ...']

# %%
from nltk.sentiment.vader import SentimentIntensityAnalyzer

sid = SentimentIntensityAnalyzer()
compound_scores1 = []

for i in text1:  
    ss = sid.polarity_scores(i)
    compound1 = ss['compound']
    compound_scores1.append(compound1)

# %%
import matplotlib.pyplot as plt
plt.figure(figsize=(12,5))
plt.plot(compound_scores1)
plt.ylabel('compound score')
plt.title('Distribution of Compound Score in  of sentiment analysis')
plt.show()
# Out:
# Text(0, 0.5, 'compound score')
# Text(0.5, 1.0, 'Distribution of Compound Score in  of sentiment analysis')

# %%
df2 = pd.read_csv('C:/Users/zhou/Desktop/BIA 660/000--Project/3 - final/transcripts.csv')
text2 = df2['transcript'][:1000]

# %%
sid = SentimentIntensityAnalyzer() #initialize
compound_scores2 = []

for i in text2:  
    ss = sid.polarity_scores(i)
    compound2 = ss['compound']
    compound_scores2.append(compound2)

# %%
plt.figure(figsize=(10,3))
plt.plot(compound_scores2)
plt.ylabel('compound score')
plt.title('Distribution of Compound Score in  of sentiment analysis')
plt.show()
# Out:
# Text(0, 0.5, 'compound score')
# Text(0.5, 1.0, 'Distribution of Compound Score in  of sentiment analysis')
